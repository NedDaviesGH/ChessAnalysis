# %%
import PyInstaller.__main__

# %%
PyInstaller.__main__.run([
    'Chess_executable.py',
    '--onefile',
    '--windowed'
])
# Out:
# 2060092 INFO: PyInstaller: 4.5.1
# 2060093 INFO: Python: 3.8.8 (conda)
# 2060094 INFO: Platform: Windows-10-10.0.19041-SP0
# 2060099 INFO: wrote C:\Users\tsadmin\PycharmProjects\Codewars\Chess_scraping\Chess_executable.spec
# 2060114 INFO: UPX is not available.
# 2060126 INFO: Extending PYTHONPATH with paths
# ['C:\\Users\\tsadmin\\PycharmProjects\\Codewars\\Chess_scraping',
#  'C:\\Users\\tsadmin\\PycharmProjects\\Codewars\\Chess_scraping']
# 2061713 INFO: checking Analysis
# 2061721 INFO: Building Analysis because Analysis-02.toc is non existent
# 2061721 INFO: Reusing cached module dependency graph...
# 2061829 INFO: Caching module graph hooks...
# 2062279 INFO: running Analysis Analysis-02.toc
# 2062288 INFO: Adding Microsoft.Windows.Common-Controls to dependent assemblies of final executable
#   required by C:\Users\tsadmin\anaconda3\python.exe
# 2062956 INFO: Analyzing C:\Users\tsadmin\PycharmProjects\Codewars\Chess_scraping\Chess_executable.py
# ...

# %%
pip install --user PyQt5==5.15.3
# Out:
# ...
#   Attempting uninstall: PyQt5
#     Found existing installation: PyQt5 5.15.4
#     Uninstalling PyQt5-5.15.4:
#       Successfully uninstalled PyQt5-5.15.4
# ...
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The scripts pylupdate5.exe, pyrcc5.exe and pyuic5.exe are installed in 'C:\Users\tsadmin\AppData\Roaming\Python\Python38\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spyder 4.2.5 requires pyqtwebengine<5.13, which is not installed.
# spyder 4.2.5 requires pyqt5<5.13, but you have pyqt5 5.15.3 which is incompatible.
